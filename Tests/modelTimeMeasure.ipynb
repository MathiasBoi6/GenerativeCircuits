# %% [markdown]
# With an untrained model it takes about 40 seconds to to do one iteration of bootstrapping. (i may be misremebering and it takes 20 for one iteration)
#
# Doing a 100 iterations take somewhere about 1 hour. But for the squarefull experiemnts, it has been taking a lot longer. With one run being projected to take over 8 hours to do 100 iterations.
#
# Therefore I will measure the time it takes for different models to generate new samples. Training time should take roughly the same amount of time for all models, so i will focus on time to do inference.
#
#
#
#
#
# Results for 256 circuits at a time:
# <table>
#  <tr>
#   <th>Subject</th>
#   <th>Allocate circuits</th>
#   <th>Use transformer</th>
#   <th>Perform inference</th>
#   <th>Total Circuit Generation Time</th>
#   <th>Clean/Prune Circuits</th>
#   <th>Hash Circuits (+ clean circuits, whoops)</th>
#   <th>Total Table Generation Time</th>
#  </tr>
#  <tr>
#   <td>Untrained Model (attempt 1)</td>
#   <td>1.994267463684082</td>
#   <td>0.023058652877807617</td>
#   <td>0.5495526790618896</td>
#   <td>2.6719603538513184</td>
#   <td>0.4429554939</td>
#   <td>0.4515459538</td>
#   <td>16.700602293014526</td>
#  </tr>
#  <tr>
#   <td>Untrained Model (attempt 2)</td>
#   <td>1.7985336780548096</td>
#   <td>0.02592921257019043</td>
#   <td>0.4643397331237793</td>
#   <td>2.3807971477508545</td>
#   <td>0.4385325909</td>
#   <td>0.4416339397</td>
#   <td>26.13381791114807</td>
#  </tr>
#  <tr>
#   <td>Untrained Model (attempt 3)</td>
#   <td>1.778602123260498</td>
#   <td>0.02400827407836914</td>
#   <td>0.6635141372680664</td>
#   <td>2.558356761932373</td>
#   <td>0.4976055622</td>
#   <td>0.4987196922</td>
#   <td>28.61220955848694</td>
#  </tr>
#  <tr>
#   <td>Squarefull Model3 (attempt 1)</td>
#   <td>1.7919652462005615</td>
#   <td>0.02425980567932129</td>
#   <td>0.6706774234771729</td>
#   <td>2.5791499614715576</td>
#   <td>0.4048621655</td>
#   <td>0.4069168568</td>
#   <td>30.856854915618896</td>
#  </tr>
#  <tr>
#   <td>Squarefull Model3 (attempt 2)</td>
#   <td>1.7969825267791748</td>
#   <td>0.023650407791137695</td>
#   <td>0.618739128112793</td>
#   <td>2.5328164100646973</td>
#   <td>0.3933184147</td>
#   <td>0.3944885731</td>
#   <td>22.694530963897705</td>
#  </tr>
#  <tr>
#   <td>Squarefull Model3 (attempt 3)</td>
#   <td>1.8004941940307617</td>
#   <td>0.024251937866210938</td>
#   <td>0.635866641998291</td>
#   <td>2.55281400680542</td>
#   <td>0.4136800766</td>
#   <td>0.4168584347</td>
#   <td>26.99513578414917</td>
#  </tr>
#  <tr>
#   <td>Squareless Model3 (attempt 1)</td>
#   <td>1.7875635623931885</td>
#   <td>0.024576425552368164</td>
#   <td>0.5363094806671143</td>
#   <td>2.441542387008667</td>
#   <td>0.3070197105</td>
#   <td>0.3080193996</td>
#   <td>0.4232821464538574</td>
#  </tr>
#  <tr>
#   <td>Squareless Model3 (attempt 2)</td>
#   <td>1.8260819911956787</td>
#   <td>0.02529311180114746</td>
#   <td>0.6334171295166016</td>
#   <td>2.576061964035034</td>
#   <td>0.3305275440</td>
#   <td>0.3340799809</td>
#   <td>0.46349430084228516</td>
#  <tr>
#   <td>Squareless Model3 (attempt 3)</td>
#   <td>1.817105770111084</td>
#   <td>0.02456498146057129</td>
#   <td>0.5445582866668701</td>
#   <td>2.478503704071045</td>
#   <td>0.3259491920</td>
#   <td>0.3289744854</td>
#   <td>0.43544602394104004</td>
#  </tr>
# </table>
#
# <table>
#  <tr>
#   <th>Subject</th>
#   <th>Allocate circuits</th>
#   <th>Use transformer</th>
#   <th>Perform inference</th>
#   <th>Total Circuit Generation Time</th>
#   <th>Clean/Prune Circuits</th>
#   <th>Hash Circuits</th>
#   <th>Total Table Generation Time</th>
#  </tr>
#  <tr>
#   <td>Untrained Model</td>
#   <td>1.857134</td>
#   <td>0.024332</td>
#   <td>0.559136</td>
#   <td>2.537038</td>
#   <td>0.459698</td>
#   <td>0.004269</td>
#   <td>23.815543</td>
#  </tr>
#  <tr>
#   <td>Squarefull Model3</td>
#   <td>1.796481</td>
#   <td>0.024054</td>
#   <td>0.641761</td>
#   <td>2.554927</td>
#   <td>0.403954</td>
#   <td>0.002134</td>
#   <td>26.848841</td>
#  </tr>
#  <tr>
#   <td>Squareless Model3</td>
#   <td>1.810250</td>
#   <td>0.024812</td>
#   <td>0.571428</td>
#   <td>2.498703</td>
#   <td>0.321165</td>
#   <td>0.002526</td>
#   <td>0.440741</td>
#  </tr>
# </table>
#
# For the untrained model observations, the same model is resued.
#
# Hashing time is unrepresentative as these times have only used the initial data set.

# %%
from bootstrapSetup import *
import time
# Out:
# dataset generated as 'loader
# embedder created as transformer
# Embedded shape: torch.Size([4, 128])
# Using device: cuda

# %%
# Hide

def checkConnectivity(connectionMap, socketMap):
    curIndex = 0
    connections = []
    exhaustedSockets = set()

    def exhaustSocketSource(socket):
        if any(not s.isSource for c in socketMap[socket] for s in connectionMap[c]): # if socket transmits to anything
            exhaustedSockets.add(socket)

        for c in socketMap[socket]:
            if c not in connections:
                connections.append(c)

    for inp, pos in inpSockets:
        exhaustSocketSource(inp)
    
    while curIndex < len(connections):
        c = connections[curIndex]
        for s in connectionMap[c]:
            if not s.isSource:
                exhaustedSockets.add(s)

            prefix, idnum, comptype = s.name

            if comptype:
                if (f"{prefix}{idnum}base" in exhaustedSockets and 
                    f"{prefix}{idnum}collector" in exhaustedSockets):
                    if f"{prefix}{idnum}emitter" not in connections and socketMap[f"{prefix}{idnum}emitter"]:
                        if any(not s.isSource for c in socketMap[f"{prefix}{idnum}emitter"] for s in connectionMap[c]):
                            exhaustSocketSource(f"{prefix}{idnum}emitter")

        curIndex += 1
    return connections, exhaustedSockets

def prePruningv2(socketMap, exhaustedSockets):
    connectedInps = []
    connectedOuts = []

    notConnectedGateIDs = []
    for s in socketMap:
        connected = s in exhaustedSockets
        prefix, idnum, comptype = s.name

        if comptype:
            if not connected and int(idnum) not in notConnectedGateIDs:
                notConnectedGateIDs.append(int(idnum))
        else:
            if connected:
                if prefix == "inp":
                    connectedInps.append(int(idnum))
                else: 
                    connectedOuts.append(int(idnum))


    return connectedInps, connectedOuts, notConnectedGateIDs

def gateRemoval(circuit, gatesToClean):
    if len(gatesToClean) == 0:
        return circuit
    
    gateToCleanIndex = 0
    curGate = 0
    for i in range(circuit.shape[0]):
        for j in range(circuit.shape[1]):
            if circuit[i][j] > 1:
                if gatesToClean[gateToCleanIndex] == curGate:
                    circuit[i][j] = 1
                    gateToCleanIndex += 1
                    if gateToCleanIndex >= len(gatesToClean):
                        return circuit

                curGate += 1
    
    return circuit


def afterPruningv2(circuit, wiresets, connectedSets):
    circuitWasUpdated = False
    for i in range(circuit.shape[0]):
        for j in range(circuit.shape[1]):
            if wiresets[i][j] not in connectedSets and circuit[i][j] == 1:
                circuit[i][j] = 0
                circuitWasUpdated = True

    return circuit, circuitWasUpdated


# Prunes excess wires from the circuit.
def CrossValue(circuit, i, j):
    up     = circuit[i - 1][j] if i > 0 else 0
    center = circuit[i][j]
    down   = circuit[i + 1][j] if i < circuit.shape[0] - 1 else 0
    left   = circuit[i][j - 1] if j > 0 else 0
    right  = circuit[i][j + 1] if j < circuit.shape[1] - 1 else 0

    return center + up + down + left + right


# Prunes excess wires from the circuit.
def pruneExcessWires(circuit):
    circuitDirty = False
    
    for j in range(1, circuit.shape[0] - 1):
        for i in range(circuit.shape[1]):
            crossValue = CrossValue(circuit, i, j)

            if crossValue < 3 and circuit[i][j] == 1:
                circuit[i][j] = 0
                circuitDirty = True


    #For end columns, allow wires connected to sockets
    for j in [0, circuit.shape[0] - 1]:
        for i in range(circuit.shape[0]):
            crossValue = CrossValue(circuit, i, j)

            if not i % 4 == 0 and crossValue < 3 and circuit[i][j] == 1:
                circuit[i][j] = 0
                circuitDirty = True
            elif i % 4 == 0 and crossValue < 2 and circuit[i][j] == 1:
                circuit[i][j] = 0
                circuitDirty = True              
    
    if circuitDirty:
        return pruneExcessWires(circuit)
    else: return circuit, circuitDirty

def requireGate(circuit):
    rows = circuit.shape[0]
    cols = circuit.shape[1]

    for i in range(rows):
        for j in range(cols):
            if circuit[i][j] > 1:
                return True
    return False

def generateSocketCombinations(inputSockets, relevantIndexes):
    #inputSockets = All available input sockets
    #relevantIndexes = the indexes of sockets that are connected to components
    
    usedSockets = [inputSockets[i][0] for i in relevantIndexes]
    
    # Generate all combinations (power set)
    orderList = []
    for r in range(len(usedSockets) + 1):
        for combo in combinations(usedSockets, r):
            orderList.append(list(combo))
    
    return orderList

# %%
# Generate N Circuits
def GenerateN(model, amount = 100):
    model.eval()
    
    t0 = time.time()
    ## GENERATE CIRCUITS
    with torch.no_grad():
        batchX = torch.randint(size=(amount, 13, 13), high = 4, low = 0, device=device )
        batchX = imageToProbabilities(batchX, 4)

        batchY = torch.randint(size=(amount, 16, 8), high = 3, low = 0, device='cpu' )
        t1 = time.time()
        print("Time to allocate circuits:", t1-t0)

        batchY = transformer(batchY).to(device)
        t2 = time.time()
        print("Time to use transformer:", t2-t1)

        
        
        # Inference with trainingsteps // 64 + 1, for faster generations. Even with this few steps, generations become perfect after training, due to small dataset.
        stepDivisor = 64
        inferenceSteps = torch.linspace(scheduler.TrainSteps-1, 1, scheduler.TrainSteps // stepDivisor, device='cpu').long()

        
        for t in inferenceSteps:
            residual_cond = model(batchX.to(device).float(), t, batchY.float()) 
            residual = F.softmax(residual_cond, dim=1)
            batchX = scheduler.addNoise(residual.to('cpu'), t - 1).float()
        batchX = F.softmax(model(batchX.to(device), 0, batchY), dim=1)

        t3 = time.time()
        print("Time of inference:", t3-t2)

        # Get circuit values
        argmaxedBatch = torch.argmax(batchX, dim=1, keepdim=True).cpu().numpy().squeeze()

        return argmaxedBatch

# %%
t0 = time.time()

t1 = time.time()

def getTablesTimed(circuits):
    #Prunes
    #Checks hashes
    #Simulates
    #Then, generates tables
    with torch.no_grad():
        tables = []
        simulatedCircuits = []
        simulatedCircuitHashes = []
        operationTimes = []

        unique_hashes = {}
        circuitsErrors = defaultdict(int)
        for i in range((circuits.shape[0])):
            circuitDirty = True # Pruning flag

            circuit = circuits[i]
            t0 = time.time()
            
            while circuitDirty:
                socketMap, wireSets = GetSocketMap(circuit, inpSockets + outSockets)
                connectionMap = GetConnectionMap(socketMap)

                connectedSets, exhaustedSockets = checkConnectivity(connectionMap, socketMap)
                inps, outs, notConnectedGateIDs = prePruningv2(socketMap, exhaustedSockets)
                circuit = gateRemoval(circuit, notConnectedGateIDs)

                socketMap, wireSets = GetSocketMap(circuit, inpSockets + outSockets)
                connectionMap = GetConnectionMap(socketMap)
                connectedSets, exhaustedSockets = checkConnectivity(connectionMap, socketMap)
                circuit, changed1 = afterPruningv2(circuit, wireSets, connectedSets)
                circuit, changed2 = pruneExcessWires(circuit)                
                circuitDirty = changed1 or changed2

            t1 = time.time()
                            
            hash = get_tensor_hash(circuit)
            t2 = time.time()

            operationTimes.append((t1-t0, t2-t0))# Time to clean circuit, time to get hash value
            if hash not in unique_hashes:
                if hash not in dataset.hashes:

                    #Get orderlist
                    if len(inps) > 1 and len(outs) > 0: # Bias to have only circuits with at least 2 inputs
                        orderlist = generateSocketCombinations(inpSockets, inps)

                        try:    
                            if requireGate(circuit):
                                truthTable = GetTruthTable(inps, outs, socketMap, connectionMap, orderlist)
                                tables.append(truthTable)
                                simulatedCircuits.append(circuit)
                                simulatedCircuitHashes.append(hash)
                                unique_hashes[hash] = i
                            else:
                                circuitsErrors["No gates"] += 1        

                        except Exception as e:
                            circuitsErrors[str(e)] += 1
                    else:
                        circuitsErrors["Not Sufficiently Connected"] += 1
                else:
                    circuitsErrors["Duplicate"] += 1
            else:
                circuitsErrors["New Duplicate"] += 1
                
        return tables, simulatedCircuits, simulatedCircuitHashes, circuitsErrors, operationTimes

# %%
model = CategoricalDiffusionModel(13, 4, 128).to(device)
#model.load_state_dict(torch.load(os.path.join("output\\2025-05-07", "SquareFull3_model.pt")))
model.load_state_dict(torch.load(os.path.join("output\\2025-05-07", "SquareLess3_model.pt")))
# Out:
# <All keys matched successfully>

# %%
t0 = time.time()
argmaxCircuits = GenerateN(model, 256)
t1 = time.time()
print("Total Time taken to generate circuits:", t1-t0)
tables, simulatedCircuits, simulatedCircuitsHashes, errors, operationTimes = getTablesTimed(argmaxCircuits)
t2 = time.time()
print("Total Time taken to generate tables:", t2-t1)
# Out:
# Time to allocate circuits: 1.817105770111084
# Time to use transformer: 0.02456498146057129
# Time of inference: 0.5445582866668701
# Total Time taken to generate circuits: 2.478503704071045
# Total Time taken to generate tables: 0.43544602394104004

# %%
# Flatten the list of tuples
cleaniningTimes = [cleaning for (cleaning, hashing) in operationTimes]
hashingimes = [hashing for (cleaning, hashing) in operationTimes]

# Convert to NumPy array for easy statistics
arr = np.array(cleaniningTimes)

# Compute statistics
average = np.mean(arr)
bottom_25 = np.percentile(arr, 25)
top_25 = np.percentile(arr, 75)

# print(f"Average: {average:.10f}")
# print(f"Bottom 25% threshold: {bottom_25:.10f}")
# print(f"Top 25% threshold: {top_25:.10f}")
print(f"Sum: {np.sum(arr):.10f}")

# Convert to NumPy array for easy statistics
arr = np.array(hashingimes)

# Compute statistics
average = np.mean(arr)
bottom_25 = np.percentile(arr, 25)
top_25 = np.percentile(arr, 75)

# print(f"Average: {average:.10f}")
# print(f"Bottom 25% threshold: {bottom_25:.10f}")
# print(f"Top 25% threshold: {top_25:.10f}")
print(f"Sum: {np.sum(arr):.10f}")
# Out:
# Sum: 0.3259491920
# Sum: 0.3289744854

# %% [markdown]
# ________
#
# How long does full inference take?

# %%
# Generate N Circuits
def GenerateNFull(model, amount, stepDivisor):
    model.eval()
    
    t0 = time.time()
    ## GENERATE CIRCUITS
    with torch.no_grad():
        batchX = torch.randint(size=(amount, 13, 13), high = 4, low = 0, device=device )
        batchX = imageToProbabilities(batchX, 4)

        batchY = torch.randint(size=(amount, 16, 8), high = 3, low = 0, device='cpu' )
        t1 = time.time()
        print("Time to allocate circuits:", t1-t0)

        batchY = transformer(batchY).to(device)
        t2 = time.time()
        print("Time to use transformer:", t2-t1)


        # Inference with trainingsteps // 64 + 1, for faster generations. Even with this few steps, generations become perfect after training, due to small dataset.
        inferenceSteps = torch.linspace(scheduler.TrainSteps-1, 1, scheduler.TrainSteps // stepDivisor, device='cpu').long()       
        
        for t in inferenceSteps:
            residual_cond = model(batchX.to(device).float(), t, batchY.float()) 
            residual = F.softmax(residual_cond, dim=1)
            batchX = scheduler.addNoise(residual.to('cpu'), t - 1).float()
        batchX = F.softmax(model(batchX.to(device), 0, batchY), dim=1)

        t3 = time.time()
        print("Time of inference:", t3-t2)

        # Get circuit values
        argmaxedBatch = torch.argmax(batchX, dim=1, keepdim=True).cpu().numpy().squeeze()

        return argmaxedBatch

# %%
t0 = time.time()
argmaxCircuits = GenerateNFull(model, 256, 1)
t1 = time.time()
print("Total Time taken to generate circuits:", t1-t0)
# Out:
# Time to allocate circuits: 2.019211769104004
# Time to use transformer: 0.02593994140625
# Time of inference: 25.309629917144775
# Total Time taken to generate circuits: 27.4683940410614

# %%
t0 = time.time()
argmaxCircuits = GenerateNFull(model, 256, 32)
t1 = time.time()
print("Total Time taken to generate circuits:", t1-t0)
# Out:
# Time to allocate circuits: 1.9339032173156738
# Time to use transformer: 0.02440953254699707
# Time of inference: 0.9816532135009766
# Total Time taken to generate circuits: 3.0526647567749023

# %%
t0 = time.time()
argmaxCircuits = GenerateNFull(model, 256, 16)
t1 = time.time()
print("Total Time taken to generate circuits:", t1-t0)
# Out:
# Time to allocate circuits: 1.9360673427581787
# Time to use transformer: 0.025742292404174805
# Time of inference: 1.680567979812622
# Total Time taken to generate circuits: 3.753129005432129

# %% [markdown]
# Roughly doubles time taken with double the amount of inference steps.
